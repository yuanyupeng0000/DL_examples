# %%
'''
A Convolutional Network implementation example using TensorFlow library.
This example is using the MNIST database of handwritten digits
(http://yann.lecun.com/exdb/mnist/)

Author: Aymeric Damien
Project: https://github.com/aymericdamien/TensorFlow-Examples/
'''

# %%
import tensorflow as tf

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Parameters
learning_rate = 0.001
training_iters = 200000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)

# %%
help(tf.placeholder)
# Out:
# Help on function placeholder in module tensorflow.python.ops.array_ops:
#
# placeholder(dtype, shape=None, name=None)
#     Inserts a placeholder for a tensor that will be always fed.
#
#     **Important**: This tensor will produce an error if evaluated. Its value must
#     be fed using the `feed_dict` optional argument to `Session.run()`,
#     `Tensor.eval()`, or `Operation.run()`.
#
#     For example:
#
#     ```python
#     x = tf.placeholder(tf.float32, shape=(1024, 1024))
#     y = tf.matmul(x, x)
#
#     with tf.Session() as sess:
#       print(sess.run(y))  # ERROR: will fail because x was not fed.
#
#       rand_array = np.random.rand(1024, 1024)
#       print(sess.run(y, feed_dict={x: rand_array}))  # Will succeed.
#     ```
#
#     Args:
#       dtype: The type of elements in the tensor to be fed.
#       shape: The shape of the tensor to be fed (optional). If the shape is not
#         specified, you can feed a tensor of any shape.
#       name: A name for the operation (optional).
#
#     Returns:
#       A `Tensor` that may be used as a handle for feeding a value, but not
#       evaluated directly.

# %%
# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out
help(tf.nn.conv2d)
# Out:
# Help on function conv2d in module tensorflow.python.ops.gen_nn_ops:
#
# conv2d(input, filter, strides, padding, use_cudnn_on_gpu=None, data_format=None, name=None)
#     Computes a 2-D convolution given 4-D `input` and `filter` tensors.
#
#     Given an input tensor of shape `[batch, in_height, in_width, in_channels]`
#     and a filter / kernel tensor of shape
#     `[filter_height, filter_width, in_channels, out_channels]`, this op
#     performs the following:
#
#     1. Flattens the filter to a 2-D matrix with shape
#        `[filter_height * filter_width * in_channels, output_channels]`.
#     2. Extracts image patches from the input tensor to form a *virtual*
#        tensor of shape `[batch, out_height, out_width,
#        filter_height * filter_width * in_channels]`.
#     3. For each patch, right-multiplies the filter matrix and the image patch
#        vector.
#
#     In detail, with the default NHWC format,
#
#         output[b, i, j, k] =
#             sum_{di, dj, q} input[b, strides[1] * i + di, strides[2] * j + dj, q] *
#                             filter[di, dj, q, k]
#
#     Must have `strides[0] = strides[3] = 1`.  For the most common case of the same
#     horizontal and vertices strides, `strides = [1, stride, stride, 1]`.
#
#     Args:
#       input: A `Tensor`. Must be one of the following types: `half`, `float32`.
#         A 4-D tensor. The dimension order is interpreted according to the value
#         of `data_format`, see below for details.
#       filter: A `Tensor`. Must have the same type as `input`.
#         A 4-D tensor of shape
#         `[filter_height, filter_width, in_channels, out_channels]`
#       strides: A list of `ints`.
#         1-D tensor of length 4.  The stride of the sliding window for each
#         dimension of `input`. The dimension order is determined by the value of
#           `data_format`, see below for details.
#       padding: A `string` from: `"SAME", "VALID"`.
#         The type of padding algorithm to use.
#       use_cudnn_on_gpu: An optional `bool`. Defaults to `True`.
#       data_format: An optional `string` from: `"NHWC", "NCHW"`. Defaults to `"NHWC"`.
#         Specify the data format of the input and output data. With the
#         default format "NHWC", the data is stored in the order of:
#             [batch, height, width, channels].
#         Alternatively, the format could be "NCHW", the data storage order of:
#             [batch, channels, height, width].
#       name: A name for the operation (optional).
#
#     Returns:
#       A `Tensor`. Has the same type as `input`.
#       A 4-D tensor. The dimension order is determined by the value of
#       `data_format`, see below for details.

# %%
# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))###############????
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.global_variables_initializer()
help(tf.reduce_mean)
# Out:
# Help on function reduce_mean in module tensorflow.python.ops.math_ops:
#
# reduce_mean(input_tensor, axis=None, keep_dims=False, name=None, reduction_indices=None)
#     Computes the mean of elements across dimensions of a tensor.
#
#     Reduces `input_tensor` along the dimensions given in `axis`.
#     Unless `keep_dims` is true, the rank of the tensor is reduced by 1 for each
#     entry in `axis`. If `keep_dims` is true, the reduced dimensions
#     are retained with length 1.
#
#     If `axis` has no entries, all dimensions are reduced, and a
#     tensor with a single element is returned.
#
#     For example:
#
#     ```python
#     # 'x' is [[1., 1.]
#     #         [2., 2.]]
#     tf.reduce_mean(x) ==> 1.5
#     tf.reduce_mean(x, 0) ==> [1.5, 1.5]
#     tf.reduce_mean(x, 1) ==> [1.,  2.]
#     ```
#
#     Args:
#       input_tensor: The tensor to reduce. Should have numeric type.
#       axis: The dimensions to reduce. If `None` (the default),
#         reduces all dimensions.
#       keep_dims: If true, retains reduced dimensions with length 1.
#       name: A name for the operation (optional).
#       reduction_indices: The old (deprecated) name for axis.
#
#     Returns:
#       The reduced tensor.
#
#     @compatibility(numpy)
#     Equivalent to np.mean
#     @end_compatibility

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
                                       keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print("Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc))
        step += 1
    print("Optimization Finished!")

    # Calculate accuracy for 256 mnist test images
    print("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256],
                                      keep_prob: 1.}))
# Out:
# Iter 1280, Minibatch Loss= 23236.402344, Training Accuracy= 0.34375
# Iter 2560, Minibatch Loss= 9403.296875, Training Accuracy= 0.60938
# Iter 3840, Minibatch Loss= 5457.389648, Training Accuracy= 0.72656
# Iter 5120, Minibatch Loss= 5150.375977, Training Accuracy= 0.78906
# Iter 6400, Minibatch Loss= 4373.975098, Training Accuracy= 0.80469
# Iter 7680, Minibatch Loss= 4502.446289, Training Accuracy= 0.84375
# Iter 8960, Minibatch Loss= 2458.708496, Training Accuracy= 0.89062
# Iter 10240, Minibatch Loss= 4538.303711, Training Accuracy= 0.85938
# Iter 11520, Minibatch Loss= 1793.116211, Training Accuracy= 0.90625
# Iter 12800, Minibatch Loss= 3992.675537, Training Accuracy= 0.87500
# Iter 14080, Minibatch Loss= 1738.894287, Training Accuracy= 0.90625
# Iter 15360, Minibatch Loss= 1905.705200, Training Accuracy= 0.92188
# Iter 16640, Minibatch Loss= 1493.844238, Training Accuracy= 0.90625
# Iter 17920, Minibatch Loss= 1173.640503, Training Accuracy= 0.89062
# Iter 19200, Minibatch Loss= 1431.767090, Training Accuracy= 0.89844
# Iter 20480, Minibatch Loss= 1171.136841, Training Accuracy= 0.93750
# Iter 21760, Minibatch Loss= 1733.892212, Training Accuracy= 0.90625
# Iter 23040, Minibatch Loss= 2146.002197, Training Accuracy= 0.90625
# Iter 24320, Minibatch Loss= 1559.388794, Training Accuracy= 0.91406
# Iter 25600, Minibatch Loss= 1996.939941, Training Accuracy= 0.95312
# Iter 26880, Minibatch Loss= 1943.702393, Training Accuracy= 0.90625
# Iter 28160, Minibatch Loss= 1213.005371, Training Accuracy= 0.90625
# Iter 29440, Minibatch Loss= 1315.025879, Training Accuracy= 0.91406
# Iter 30720, Minibatch Loss= 146.639816, Training Accuracy= 0.98438
# Iter 32000, Minibatch Loss= 1494.439087, Training Accuracy= 0.94531
# Iter 33280, Minibatch Loss= 1966.529907, Training Accuracy= 0.94531
# Iter 34560, Minibatch Loss= 770.153687, Training Accuracy= 0.95312
# Iter 35840, Minibatch Loss= 309.991821, Training Accuracy= 0.98438
# Iter 37120, Minibatch Loss= 1214.702759, Training Accuracy= 0.95312
# Iter 38400, Minibatch Loss= 632.745605, Training Accuracy= 0.96094
# Iter 39680, Minibatch Loss= 1014.796753, Training Accuracy= 0.96094
# Iter 40960, Minibatch Loss= 1729.941895, Training Accuracy= 0.93750
# Iter 42240, Minibatch Loss= 1420.707031, Training Accuracy= 0.95312
# Iter 43520, Minibatch Loss= 1195.000977, Training Accuracy= 0.92969
# Iter 44800, Minibatch Loss= 1700.451904, Training Accuracy= 0.92969
# Iter 46080, Minibatch Loss= 941.699097, Training Accuracy= 0.96094
# Iter 47360, Minibatch Loss= 888.416382, Training Accuracy= 0.93750
# Iter 48640, Minibatch Loss= 1008.857666, Training Accuracy= 0.96094
# Iter 49920, Minibatch Loss= 726.620605, Training Accuracy= 0.95312
# Iter 51200, Minibatch Loss= 1108.774170, Training Accuracy= 0.92188
# Iter 52480, Minibatch Loss= 816.073547, Training Accuracy= 0.93750
# Iter 53760, Minibatch Loss= 87.836258, Training Accuracy= 0.98438
# Iter 55040, Minibatch Loss= 318.360260, Training Accuracy= 0.96094
# Iter 56320, Minibatch Loss= 518.861877, Training Accuracy= 0.95312
# Iter 57600, Minibatch Loss= 835.888794, Training Accuracy= 0.92969
# Iter 58880, Minibatch Loss= 460.160431, Training Accuracy= 0.96875
# Iter 60160, Minibatch Loss= 578.454224, Training Accuracy= 0.90625
# Iter 61440, Minibatch Loss= 689.023071, Training Accuracy= 0.94531
# Iter 62720, Minibatch Loss= 683.041870, Training Accuracy= 0.96094
# Iter 64000, Minibatch Loss= 159.514938, Training Accuracy= 0.97656
# Iter 65280, Minibatch Loss= 752.084167, Training Accuracy= 0.92969
# Iter 66560, Minibatch Loss= 577.781006, Training Accuracy= 0.94531
# Iter 67840, Minibatch Loss= 224.239197, Training Accuracy= 0.96875
# Iter 69120, Minibatch Loss= 422.990082, Training Accuracy= 0.96875
# Iter 70400, Minibatch Loss= 353.666565, Training Accuracy= 0.97656
# Iter 71680, Minibatch Loss= 507.408936, Training Accuracy= 0.96094
# Iter 72960, Minibatch Loss= 749.463684, Training Accuracy= 0.94531
# Iter 74240, Minibatch Loss= 785.360840, Training Accuracy= 0.94531
# Iter 75520, Minibatch Loss= 133.418564, Training Accuracy= 0.97656
# Iter 76800, Minibatch Loss= 885.965515, Training Accuracy= 0.91406
# Iter 78080, Minibatch Loss= 866.813843, Training Accuracy= 0.93750
# Iter 79360, Minibatch Loss= 561.662720, Training Accuracy= 0.96094
# Iter 80640, Minibatch Loss= 88.489021, Training Accuracy= 0.98438
# Iter 81920, Minibatch Loss= 149.751465, Training Accuracy= 0.99219
# Iter 83200, Minibatch Loss= 53.872711, Training Accuracy= 0.97656
# Iter 84480, Minibatch Loss= 78.909973, Training Accuracy= 0.99219
# Iter 85760, Minibatch Loss= 764.029053, Training Accuracy= 0.93750
# Iter 87040, Minibatch Loss= 1147.817139, Training Accuracy= 0.95312
# Iter 88320, Minibatch Loss= 345.984680, Training Accuracy= 0.94531
# Iter 89600, Minibatch Loss= 640.242859, Training Accuracy= 0.95312
# Iter 90880, Minibatch Loss= 318.370361, Training Accuracy= 0.96094
# Iter 92160, Minibatch Loss= 471.201599, Training Accuracy= 0.96875
# Iter 93440, Minibatch Loss= 320.183716, Training Accuracy= 0.98438
# Iter 94720, Minibatch Loss= 460.724121, Training Accuracy= 0.95312
# Iter 96000, Minibatch Loss= 601.827148, Training Accuracy= 0.94531
# Iter 97280, Minibatch Loss= 170.763519, Training Accuracy= 0.96875
# Iter 98560, Minibatch Loss= 320.102722, Training Accuracy= 0.96875
# Iter 99840, Minibatch Loss= 210.776123, Training Accuracy= 0.96094
# Iter 101120, Minibatch Loss= 445.618286, Training Accuracy= 0.96094
# Iter 102400, Minibatch Loss= 160.857758, Training Accuracy= 0.96094
# Iter 103680, Minibatch Loss= 264.403168, Training Accuracy= 0.98438
# Iter 104960, Minibatch Loss= 174.574554, Training Accuracy= 0.98438
# Iter 106240, Minibatch Loss= 317.210144, Training Accuracy= 0.96094
# Iter 107520, Minibatch Loss= 219.046371, Training Accuracy= 0.98438
# Iter 108800, Minibatch Loss= 238.343399, Training Accuracy= 0.97656
# Iter 110080, Minibatch Loss= 117.896233, Training Accuracy= 0.96875
# Iter 111360, Minibatch Loss= 206.804230, Training Accuracy= 0.96875
# Iter 112640, Minibatch Loss= 926.073120, Training Accuracy= 0.96094
# Iter 113920, Minibatch Loss= 237.843231, Training Accuracy= 0.97656
# Iter 115200, Minibatch Loss= 195.205856, Training Accuracy= 0.97656
# Iter 116480, Minibatch Loss= 124.976074, Training Accuracy= 0.98438
# Iter 117760, Minibatch Loss= 412.341583, Training Accuracy= 0.96094
# Iter 119040, Minibatch Loss= 552.538940, Training Accuracy= 0.96875
# Iter 120320, Minibatch Loss= 252.179581, Training Accuracy= 0.96875
# Iter 121600, Minibatch Loss= 221.005814, Training Accuracy= 0.95312
# Iter 122880, Minibatch Loss= 273.561920, Training Accuracy= 0.97656
# Iter 124160, Minibatch Loss= 214.400146, Training Accuracy= 0.95312
# Iter 125440, Minibatch Loss= 233.046753, Training Accuracy= 0.96875
# Iter 126720, Minibatch Loss= 166.120087, Training Accuracy= 0.96094
# Iter 128000, Minibatch Loss= 37.233788, Training Accuracy= 0.99219
# Iter 129280, Minibatch Loss= 151.233002, Training Accuracy= 0.97656
# Iter 130560, Minibatch Loss= 175.681351, Training Accuracy= 0.96875
# Iter 131840, Minibatch Loss= 344.977142, Training Accuracy= 0.95312
# Iter 133120, Minibatch Loss= 291.516022, Training Accuracy= 0.96875
# Iter 134400, Minibatch Loss= 148.504578, Training Accuracy= 0.97656
# Iter 135680, Minibatch Loss= 168.470383, Training Accuracy= 0.99219
# Iter 136960, Minibatch Loss= 114.726059, Training Accuracy= 0.96094
# Iter 138240, Minibatch Loss= 35.296066, Training Accuracy= 0.98438
# Iter 139520, Minibatch Loss= 180.221344, Training Accuracy= 0.98438
# Iter 140800, Minibatch Loss= 153.858139, Training Accuracy= 0.97656
# Iter 142080, Minibatch Loss= 9.998993, Training Accuracy= 0.97656
# Iter 143360, Minibatch Loss= 118.720909, Training Accuracy= 0.97656
# Iter 144640, Minibatch Loss= 20.049866, Training Accuracy= 0.99219
# Iter 145920, Minibatch Loss= 83.262863, Training Accuracy= 0.96875
# Iter 147200, Minibatch Loss= 221.501831, Training Accuracy= 0.97656
# Iter 148480, Minibatch Loss= 146.517975, Training Accuracy= 0.97656
# Iter 149760, Minibatch Loss= 19.699486, Training Accuracy= 0.98438
# Iter 151040, Minibatch Loss= 18.584778, Training Accuracy= 0.99219
# Iter 152320, Minibatch Loss= 564.879883, Training Accuracy= 0.97656
# Iter 153600, Minibatch Loss= 280.277161, Training Accuracy= 0.97656
# Iter 154880, Minibatch Loss= 275.217926, Training Accuracy= 0.96875
# Iter 156160, Minibatch Loss= 165.082062, Training Accuracy= 0.94531
# Iter 157440, Minibatch Loss= 7.528458, Training Accuracy= 0.99219
# Iter 158720, Minibatch Loss= 552.193848, Training Accuracy= 0.95312
# Iter 160000, Minibatch Loss= 188.803192, Training Accuracy= 0.96094
# Iter 161280, Minibatch Loss= 139.948212, Training Accuracy= 0.97656
# Iter 162560, Minibatch Loss= 72.842072, Training Accuracy= 0.97656
# Iter 163840, Minibatch Loss= 182.867889, Training Accuracy= 0.97656
# Iter 165120, Minibatch Loss= 374.781708, Training Accuracy= 0.95312
# Iter 166400, Minibatch Loss= 27.201904, Training Accuracy= 0.99219
# Iter 167680, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 168960, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 170240, Minibatch Loss= 63.592255, Training Accuracy= 0.99219
# Iter 171520, Minibatch Loss= 287.482666, Training Accuracy= 0.96094
# Iter 172800, Minibatch Loss= 311.781525, Training Accuracy= 0.96875
# Iter 174080, Minibatch Loss= 409.390137, Training Accuracy= 0.96875
# Iter 175360, Minibatch Loss= 399.688293, Training Accuracy= 0.96875
# Iter 176640, Minibatch Loss= 66.089096, Training Accuracy= 0.98438
# Iter 177920, Minibatch Loss= 140.954422, Training Accuracy= 0.96094
# Iter 179200, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 180480, Minibatch Loss= 168.670700, Training Accuracy= 0.98438
# Iter 181760, Minibatch Loss= 108.022751, Training Accuracy= 0.98438
# Iter 183040, Minibatch Loss= 530.047485, Training Accuracy= 0.96094
# Iter 184320, Minibatch Loss= 4.923538, Training Accuracy= 0.99219
# Iter 185600, Minibatch Loss= 75.933151, Training Accuracy= 0.96094
# Iter 186880, Minibatch Loss= 223.637802, Training Accuracy= 0.96875
# Iter 188160, Minibatch Loss= 240.073273, Training Accuracy= 0.96875
# Iter 189440, Minibatch Loss= 150.599274, Training Accuracy= 0.98438
# Iter 190720, Minibatch Loss= 1.615295, Training Accuracy= 0.99219
# Iter 192000, Minibatch Loss= 58.128555, Training Accuracy= 0.99219
# Iter 193280, Minibatch Loss= 808.403076, Training Accuracy= 0.94531
# Iter 194560, Minibatch Loss= 154.048782, Training Accuracy= 0.99219
# Iter 195840, Minibatch Loss= 126.717598, Training Accuracy= 0.98438
# Iter 197120, Minibatch Loss= 209.114197, Training Accuracy= 0.96875
# Iter 198400, Minibatch Loss= 207.075424, Training Accuracy= 0.96875
# Iter 199680, Minibatch Loss= 195.838104, Training Accuracy= 0.97656
# Optimization Finished!
# Testing Accuracy: 0.992188
